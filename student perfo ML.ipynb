# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
path=r'C:\Users\RDP16\Downloads\Student_performance_data _.csv'
path
# Out:
# 'C:\\Users\\RDP16\\Downloads\\Student_performance_data _.csv'

# %%
data=pd.read_csv(path)
data.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
data.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
sns.countplot(data=data,x='GradeClass')
# Out:
# <Axes: xlabel='GradeClass', ylabel='count'>

# %%
sns.countplot(data=data,x='GradeClass',hue='Gender')
# Out:
# <Axes: xlabel='GradeClass', ylabel='count'>

# %%
sns.histplot(data=data,x='GradeClass',hue='Gender')
# Out:
# <Axes: xlabel='GradeClass', ylabel='Count'>

# %%
g=sns.FacetGrid(data,col='Gender',hue='Gender')
g.map_dataframe(sns.histplot,x='GradeClass')
g.add_legend()

# %% [markdown]
# ### check relation between studytimeweekly and Gradeclass

# %%
sns.boxplot(data=data,x='GradeClass',y='StudyTimeWeekly',hue='Gender')
# Out:
# <Axes: xlabel='GradeClass', ylabel='StudyTimeWeekly'>

# %%
sns.barplot(data=data,x='GradeClass',y='StudyTimeWeekly',hue='Gender')
# Out:
# <Axes: xlabel='GradeClass', ylabel='StudyTimeWeekly'>

# %% [markdown]
# ### relationship betweeen Ethnicity (kalla,goge) and GradeClass

# %%
sns.countplot(data=data,x='Ethnicity',hue='GradeClass')
# Out:
# <Axes: xlabel='Ethnicity', ylabel='count'>

# %%
sns.boxplot(data=data,x='GradeClass',y='Absences')
# Out:
# <Axes: xlabel='GradeClass', ylabel='Absences'>

# %%
sns.countplot(data=data,x='ParentalSupport',hue='GradeClass')
# Out:
# <Axes: xlabel='ParentalSupport', ylabel='count'>

# %%
g=sns.FacetGrid(data,col='Gender',hue='Gender')
g.map_dataframe(sns.histplot,x='GradeClass',hue='Tutoring')
g.add_legend()

# %%
g=sns.FacetGrid(data,col='Gender',hue='Gender')
g.map_dataframe(sns.histplot,x='GradeClass',hue='Extracurricular')
g.add_legend()

# %%
sns.countplot(data=data,x='GradeClass',hue='Extracurricular')
# Out:
# <Axes: xlabel='GradeClass', ylabel='count'>

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()
rs
# Out:
# RobustScaler()

# %%
data[['StudyTimeWeekly','Absences']]=rs.fit_transform(data[['StudyTimeWeekly','Absences']])
data
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2         1.081474
# 1          1002   18       0          0                  1         0.608990
# 2          1003   15       0          2                  3        -0.586716
# 3          1004   17       1          0                  3         0.034539
# 4          1005   17       1          0                  2        -0.537394
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3         0.104128
# 2388       3389   17       0          0                  1        -0.226596
# 2389       3390   16       1          0                  2        -0.309638
# 2390       3391   16       1          1                  0         0.289503
# 2391       3392   16       1          0                  2         0.866445
#
# ...
