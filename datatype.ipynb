# %%
titanic 
columns name=PassengerId	Survived	Pclass	Name	Sex	Age		SibSp	Parch	Ticket	Fare	Cabin	Embarked
discreet = surivied 	pclass 	embarked	sex 	SibSp	Parch
continous=age	ticket	fare
nomial= name 	ticket	Cabin
ordinal=pclass
# Out:
#   Cell In[1], line 2
#     columns name=PassengerId	Survived	Pclass	Name	Sex	Age		SibSp	Parch	Ticket	Fare	Cabin	Embarked
#             ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd

# %%
url=r'https://raw.githubusercontent.com/AIbot7/Dataset/master/zomato.csv'

# %%
data=pd.read_csv(url,encoding='latin-1')
data.head(20)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# ...

# %% [markdown]
# # zomato dataset coulmns
# columns name=Restaurant ID	Restaurant Name	Country Code	City	Address	Locality	Locality Verbose	Longitude	Latitude	Cuisines	...	Currency	Has Table booking	Has Online delivery	Is delivering now	Switch to order menu	Price range	Aggregate rating	Rating color	Rating text	Votes
#
#
# nomial=Restaurant name	 ,city	,address	,Cuisiness	,locality	,Locality Verbose
#
# continous=country code	,Longitud,	Latitude	,average cost of twos	,aggregate rating,Votes
#
# discreet=Has Table booking	,as Online delivery	,Is delivering now	Switch to order menu,	Price range	,	Rating color,	Rating text	,currency

# %% [markdown]
# # chipotle dataset columns
# columns names =order_id	quantity	item_name	choice_description	item_price
# nomial=item_name	choice_description
# continous==order_id	item_price
# discreet=quantity

# %%
url=r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'

# %%
data=pd.read_csv(url,encoding='latin-1')
data.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# ...

# %% [markdown]
# # alcohol consumption
# column name=country	beer_servings	spirit_servings	wine_servings	total_litres_of_pure_alcohol	continent
#
# nomial=beer_servings	spirit_servings	wine_servings
#
# continous=	total_litres_of_pure_alcohol
#
# ordinal=country
#
# discreet=country,continent
