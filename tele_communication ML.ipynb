# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\RDP16\Downloads\Telco_Customer_Churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df['TotalCharges']=df['TotalCharges'].str.replace(' ','NaN')

# %%
df['TotalCharges']=df['TotalCharges'].astype(float)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.isnull().sum().sum()
# Out:
# 11

# %%
df=df.fillna(method='ffill')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()
rs
# Out:
# RobustScaler()

# %%
df[['tenure','MonthlyCharges','TotalCharges']]=rs.fit_transform(df[['tenure','MonthlyCharges','TotalCharges']])
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents    tenure  \
# 0     7590-VHVEG  Female              0     Yes         No -0.608696
# 1     5575-GNVDE    Male              0      No         No  0.108696
# 2     3668-QPYBK    Male              0      No         No -0.586957
# 3     7795-CFOCW    Male              0      No         No  0.347826
# 4     9237-HQITU  Female              0      No         No -0.586957
# ...          ...     ...            ...     ...        ...       ...
# 7038  6840-RESVB    Male              0     Yes        Yes -0.108696
# 7039  2234-XADUH  Female              0     Yes        Yes  0.934783
# 7040  4801-JZAZL  Female              0     Yes        Yes -0.391304
# 7041  8361-LTMKD    Male              1     Yes         No -0.543478
# 7042  3186-AJIEK    Male              0      No         No  0.804348
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
# churn- customer chodke jarahe

# %%
df=df.drop(columns=['customerID','Partner','Dependents'])
df
# Out:
#       gender  SeniorCitizen    tenure PhoneService     MultipleLines  \
# 0     Female              0 -0.608696           No  No phone service
# 1       Male              0  0.108696          Yes                No
# 2       Male              0 -0.586957          Yes                No
# 3       Male              0  0.347826           No  No phone service
# 4     Female              0 -0.586957          Yes                No
# ...      ...            ...       ...          ...               ...
# 7038    Male              0 -0.108696          Yes               Yes
# 7039  Female              0  0.934783          Yes               Yes
# 7040  Female              0 -0.391304           No  No phone service
# 7041    Male              1 -0.543478          Yes               Yes
# 7042    Male              0  0.804348          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# ...

# %%
pd.get_dummies(df,dtype='int',drop_first=True)
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0                 0 -0.608696       -0.745170     -0.402308            0
# 1                 0  0.108696       -0.246550      0.144427            1
# 2                 0 -0.586957       -0.303588     -0.379288            1
# 3                 0  0.347826       -0.516099      0.130094            1
# 4                 0 -0.586957        0.006440     -0.366499            0
# ...             ...       ...             ...           ...          ...
# 7038              0 -0.108696        0.265869      0.174121            1
# 7039              0  0.934783        0.604416      1.753600            0
# 7040              0 -0.391304       -0.749770     -0.309228            0
# 7041              1 -0.543478        0.074517     -0.320944            1
# 7042              0  0.804348        0.649494      1.601191            1
#
#       PhoneService_Yes  MultipleLines_No phone service  MultipleLines_Yes  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
ohe
# Out:
# OneHotEncoder()

# %%
ohe.fit_transform(df)
# Out:
# <7043x8229 sparse matrix of type '<class 'numpy.float64'>'
# 	with 126774 stored elements in Compressed Sparse Row format>
